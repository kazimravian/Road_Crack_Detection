# %% [markdown]
# **Import Required Libraries**

# %%
# !pip install roboflow
# !pip install ultralytics==8.0.196

# %% [markdown]
# **Load Dataset**

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="lWjBywj3M1I4YI09jTmu")
project = rf.workspace("road-crack-project").project("road-crack-detection-combined-dataset")
version = project.version(2)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Road-Crack-Detection-Combined-Dataset-2 to yolov5pytorch:: 100%|██████████| 138617/138617 [00:08<00:00, 15708.92it/s]
# Extracting Dataset Version Zip to Road-Crack-Detection-Combined-Dataset-2 in yolov5pytorch:: 100%|██████████| 3510/3510 [00:01<00:00, 1989.92it/s]

# %% [markdown]
# **Create Yolo V3 Object Detection Model**

# %%
from ultralytics import YOLO

# %%
# Load a model
model = YOLO("yolov3n.yaml")
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 1]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     37056  ultralytics.nn.modules.block.Bottleneck      [64, 64]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    295680  ultralytics.nn.modules.block.Bottleneck      [128, 128]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  8   4724736  ultralytics.nn.modules.block.Bottleneck      [256, 256]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  8  18886656  ultralytics.nn.modules.block.Bottleneck      [512, 512]
#   9                  -1  1   4720640  ultralytics.nn.modules.conv.Conv             [512, 1024, 3, 2]
#  10                  -1  4  37761024  ultralytics.nn.modules.block.Bottleneck      [1024, 1024]
#  11                  -1  1   9440256  ultralytics.nn.modules.block.Bottleneck      [1024, 1024, False]
#  12                  -1  1    525312  ultralytics.nn.modules.conv.Conv             [1024, 512, 1, 1]
#  13                  -1  1   4720640  ultralytics.nn.modules.conv.Conv             [512, 1024, 3, 1]
#  14                  -1  1    525312  ultralytics.nn.modules.conv.Conv             [1024, 512, 1, 1]
#  15                  -1  1   4720640  ultralytics.nn.modules.conv.Conv             [512, 1024, 3, 1]
#  16                  -2  1    131584  ultralytics.nn.modules.conv.Conv             [512, 256, 1, 1]
#  17                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  18             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   2950656  ultralytics.nn.modules.block.Bottleneck      [768, 512, False]
#  20                  -1  1   2360832  ultralytics.nn.modules.block.Bottleneck      [512, 512, False]
#  21                  -1  1    131584  ultralytics.nn.modules.conv.Conv             [512, 256, 1, 1]
#  22                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 1]
#  23                  -2  1     33024  ultralytics.nn.modules.conv.Conv             [256, 128, 1, 1]
#  24                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  25             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  26                  -1  1    738048  ultralytics.nn.modules.block.Bottleneck      [384, 256, False]
#  27                  -1  2   1181184  ultralytics.nn.modules.block.Bottleneck      [256, 256, False]
#  28        [27, 22, 15]  1   7119040  ultralytics.nn.modules.head.Detect           [80, [256, 512, 1024]]
# YOLOv3n summary: 310 layers, 103754144 parameters, 103754128 gradients, 283.3 GFLOPs

# %% [markdown]
# **Train the Yolo V3 Model on Road Crack Dataset**

# %%
# train the model
results = model.train(data = '/content/Road-Crack-Detection-Combined-Dataset-2/data.yaml', epochs = 50)
# Out:
# New https://pypi.org/project/ultralytics/8.2.19 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# engine/trainer: task=detect, mode=train, model=yolov3n.yaml, data=/content/Road-Crack-Detection-Combined-Dataset-2/data.yaml, epochs=50, patience=50, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train2
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100%|██████████| 755k/755k [00:00<00:00, 125MB/s]
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 1]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     37056  ultralytics.nn.modules.block.Bottleneck      [64, 64]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    295680  ultralytics.nn.modules.block.Bottleneck      [128, 128]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  8   4724736  ultralytics.nn.modules.block.Bottleneck      [256, 256]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  8  18886656  ultralytics.nn.modules.block.Bottleneck      [512, 512]
#   9                  -1  1   4720640  ultralytics.nn.modules.conv.Conv             [512, 1024, 3, 2]
#  10                  -1  4  37761024  ultralytics.nn.modules.block.Bottleneck      [1024, 1024]
#  11                  -1  1   9440256  ultralytics.nn.modules.block.Bottleneck      [1024, 1024, False]
#  12                  -1  1    525312  ultralytics.nn.modules.conv.Conv             [1024, 512, 1, 1]
#  13                  -1  1   4720640  ultralytics.nn.modules.conv.Conv             [512, 1024, 3, 1]
#  14                  -1  1    525312  ultralytics.nn.modules.conv.Conv             [1024, 512, 1, 1]
#  15                  -1  1   4720640  ultralytics.nn.modules.conv.Conv             [512, 1024, 3, 1]
#  16                  -2  1    131584  ultralytics.nn.modules.conv.Conv             [512, 256, 1, 1]
#  17                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  18             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   2950656  ultralytics.nn.modules.block.Bottleneck      [768, 512, False]
#  20                  -1  1   2360832  ultralytics.nn.modules.block.Bottleneck      [512, 512, False]
#  21                  -1  1    131584  ultralytics.nn.modules.conv.Conv             [512, 256, 1, 1]
#  22                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 1]
#  23                  -2  1     33024  ultralytics.nn.modules.conv.Conv             [256, 128, 1, 1]
#  24                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  25             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  26                  -1  1    738048  ultralytics.nn.modules.block.Bottleneck      [384, 256, False]
#  27                  -1  2   1181184  ultralytics.nn.modules.block.Bottleneck      [256, 256, False]
#  28        [27, 22, 15]  1   7060444  ultralytics.nn.modules.head.Detect           [4, [256, 512, 1024]]
# YOLOv3n summary: 310 layers, 103695548 parameters, 103695532 gradients, 283.0 GFLOPs
#
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train2', view at http://localhost:6006/
# Freezing layer 'model.28.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 197MB/s]
# Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
# WARNING ⚠️ NMS time limit 0.550s exceeded
# AMP: checks passed ✅
# train: Scanning /content/Road-Crack-Detection-Combined-Dataset-2/train/labels... 1392 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1392/1392 [00:00<00:00, 1834.10it/s]
# train: New cache created: /content/Road-Crack-Detection-Combined-Dataset-2/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
# val: Scanning /content/Road-Crack-Detection-Combined-Dataset-2/valid/labels... 190 images, 0 backgrounds, 0 corrupt: 100%|██████████| 190/190 [00:00<00:00, 515.65it/s]
# val: New cache created: /content/Road-Crack-Detection-Combined-Dataset-2/valid/labels.cache
# Plotting labels to runs/detect/train2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 84 weight(decay=0.0), 91 weight(decay=0.0005), 90 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/detect/train2
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      13.3G      3.859      4.519      4.037         56        640: 100%|██████████| 87/87 [01:51<00:00,  1.28s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:05<00:00,  1.07it/s]
#                    all        190        396      0.251     0.0456   0.000203   3.85e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      14.2G      3.316      3.826      3.432         80        640: 100%|██████████| 87/87 [01:52<00:00,  1.29s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:03<00:00,  1.63it/s]
#                    all        190        396      0.513     0.0403    0.00757    0.00193
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      13.5G      3.093      3.538      3.099         45        640: 100%|██████████| 87/87 [01:51<00:00,  1.29s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:03<00:00,  1.60it/s]
#                    all        190        396    0.00993      0.285     0.0126    0.00334
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      14.1G      2.894      3.266      2.864         70        640: 100%|██████████| 87/87 [01:51<00:00,  1.28s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:03<00:00,  1.54it/s]
#                    all        190        396     0.0278       0.25     0.0218    0.00579
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      13.9G      2.785       3.13      2.757         71        640: 100%|██████████| 87/87 [01:52<00:00,  1.29s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:03<00:00,  1.54it/s]
#                    all        190        396     0.0922      0.124     0.0463     0.0117
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      13.7G      2.679      2.999      2.625         47        640: 100%|██████████| 87/87 [01:51<00:00,  1.29s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:04<00:00,  1.47it/s]
#                    all        190        396      0.296      0.258     0.0493     0.0129
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      14.2G      2.576      2.824       2.51         57        640: 100%|██████████| 87/87 [01:52<00:00,  1.29s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:04<00:00,  1.42it/s]
#                    all        190        396      0.561       0.16     0.0786     0.0236
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      14.1G      2.535      2.808      2.465         66        640: 100%|██████████| 87/87 [01:51<00:00,  1.29s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:03<00:00,  1
hours.
# Optimizer stripped from runs/detect/train2/weights/last.pt, 207.7MB
# Optimizer stripped from runs/detect/train2/weights/best.pt, 207.7MB
#
# Validating runs/detect/train2/weights/best.pt...
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv3n summary (fused): 226 layers, 103667324 parameters, 0 gradients, 282.2 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:07<00:00,  1.32s/it]
#                    all        190        396      0.548      0.436      0.484      0.246
#              Crocodile        190        100      0.714      0.748      0.774      0.457
#           Longitudinal        190        174       0.62      0.489       0.51      0.237
#                Pothole        190          5       0.27        0.2      0.216      0.142
#             Transverse        190        117       0.59      0.307      0.434      0.146
# Speed: 0.2ms preprocess, 15.5ms inference, 0.0ms loss, 5.1ms postprocess per image
# Results saved to runs/detect/train2

# %% [markdown]
# **Training Results**

# %%
import pandas as pd

train_results = pd.read_csv("/content/runs/detect/train2/results.csv")
train_results.tail()
# Out:
#                       epoch           train/box_loss           train/cls_loss  \
# 45                       46                   1.7585                   1.6598
# 46                       47                   1.6961                   1.6056
# 47                       48                   1.6742                   1.5705
# 48                       49                   1.6655                   1.5622
# 49                       50                   1.6390                   1.5288
#
#              train/dfl_loss     metrics/precision(B)        metrics/recall(B)  \
# 45                   1.8160                  0.48068                  0.40731
# 46                   1.7773                  0.62052                  0.38161
# 47                   1.7628                  0.50233                  0.43298
# 48                   1.7433                  0.52940                  0.44494
# 49                   1.7351                  0.49613                  0.43511
#
#            metrics/mAP50(B)      metrics/mAP50-95(B)             val/box_loss  \
# 45                  0.43164                  0.21354                   1.9058
# 46                  0.45819                  0.22852                   1.9309
# 47                  0.43498                  0.21571                   1.9251
# 48                  0.45066                  0.22208                   1.8779
# 49                  0.42492                  0.20870                   1.9371
#
#                val/cls_loss             val/dfl_loss                   lr/pg0  \
# 45                   1.7321                   2.0666                 0.000161
# 46                   1.7206                   2.0595                 0.000136
# 47                   1.7799                   2.0592                 0.000111
# 48                   1.6789                   2.0391                 0.000087
# 49                   1.7705                   2.0845                 0.000062
#
#                      lr/pg1                   lr/pg2
# 45                 0.000161                 0.000161
# 46                 0.000136                 0.000136
# 47                 0.000111                 0.000111
# 48                 0.000087                 0.000087
# 49                 0.000062                 0.000062

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (10, 10))
train_res = plt.imread("/content/runs/detect/train2/results.png")
plt.imshow(train_res)
plt.axis("off")
# Out:
# (-0.5, 2399.5, 1199.5, -0.5)

# %% [markdown]
# **R_curve**

# %%
import matplotlib.pyplot as plt

# Load the image
r_curve = plt.imread("/content/runs/detect/train2/R_curve.png")

# Create a figure with a higher DPI
fig, ax = plt.subplots(dpi=150)

# Display the image
ax.imshow(r_curve)
ax.axis("off")

# Show the plot
plt.show()

# %% [markdown]
# **P-Curve**

# %%
import matplotlib.pyplot as plt

# Load the image
r_curve = plt.imread("/content/runs/detect/train2/P_curve.png")

# Create a figure with a higher DPI
fig, ax = plt.subplots(dpi=150)

# Display the image
ax.imshow(r_curve)
ax.axis("off")

# Show the plot
plt.show()

# %% [markdown]
# **PR_curve**

# %%
import matplotlib.pyplot as plt

# Load the image
r_curve = plt.imread("/content/runs/detect/train2/PR_curve.png")

# Create a figure with a higher DPI
fig, ax = plt.subplots(dpi=150)

# Display the image
ax.imshow(r_curve)
ax.axis("off")

# Show the plot
plt.show()

# %% [markdown]
# **F1_curve**

# %%
import matplotlib.pyplot as plt

# Load the image
r_curve = plt.imread("/content/runs/detect/train2/F1_curve.png")

# Create a figure with a higher DPI
fig, ax = plt.subplots(dpi=150)

# Display the image
ax.imshow(r_curve)
ax.axis("off")

# Show the plot
plt.show()

# %% [markdown]
# **Confusion Matrix**

# %%
# Load the image
r_curve = plt.imread("/content/runs/detect/train2/confusion_matrix_normalized.png")

# Create a figure with a higher DPI
fig, ax = plt.subplots(dpi=200)

# Display the image
ax.imshow(r_curve)
ax.axis("off")

# Show the plot
plt.show()

# %% [markdown]
# **Validate results the Yolo V3 on Validation Dataset**

# %% [markdown]
# **R_curve**

# %%
model.val()
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv3n summary (fused): 226 layers, 103667324 parameters, 0 gradients, 282.2 GFLOPs
# val: Scanning /content/Road-Crack-Detection-Combined-Dataset-2/valid/labels.cache... 190 images, 0 backgrounds, 0 corrupt: 100%|██████████| 190/190 [00:00<?, ?it/s]
# os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 12/12 [00:10<00:00,  1.10it/s]
#                    all        190        396      0.548      0.436      0.483      0.245
#              Crocodile        190        100      0.712       0.75      0.773      0.457
#           Longitudinal        190        174      0.621      0.489       0.51      0.235
#                Pothole        190          5       0.27        0.2      0.216      0.142
#             Transverse        190        117      0.589      0.306      0.433      0.145
# Speed: 0.8ms preprocess, 34.6ms inference, 0.0ms loss, 3.7ms postprocess per image
# Results saved to runs/detect/val
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0, 1, 2, 3])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7967b90580a0>
# fitness: 0.2685443086724115
# keys: ['metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)']
# maps: array([    0.45686,     0.23472,     0.14222,     0.14495])
# names: {0: 'Crocodile', 1: 'Longitudinal', 2: 'Pothole', 3: 'Transverse'}
# plot: True
# results_dict: {'metrics/precision(B)': 0.5481602238103067, 'metrics/recall(B)': 0.4362159940836024, 'metrics/mAP50(B)': 0.4832601664086502, 'metrics/mAP50-95(B)': 0.24468699114616274, 'fitness': 0.2685443086724115}
# save_dir: PosixPath('runs/detect/val')
# speed: {'preprocess': 0.8488316284982781, 'inference': 34.59029323176334, 'loss': 0.0015170950638620478, 'postprocess': 3.7054576371845447}

# %%
import matplotlib.pyplot as plt

# Load the image
r_curve = plt.imread("/content/runs/detect/val/R_curve.png")

# Create a figure with a higher DPI
fig, ax = plt.subplots(dpi=150)

# Display the image
ax.imshow(r_curve)
ax.axis("off")

# Show the plot
plt.show()

# %% [markdown]
# **P-Curve**

# %%
import matplotlib.pyplot as plt

# Load the image
r_curve = plt.imread("/content/runs/detect/val/P_curve.png")

# Create a figure with a higher DPI
fig, ax = plt.subplots(dpi=150)

# Display the image
ax.imshow(r_curve)
ax.axis("off")

# Show the plot
plt.show()

# %% [markdown]
# **PR_curve**

# %%
import matplotlib.pyplot as plt

# Load the image
r_curve = plt.imread("/content/runs/detect/val/PR_curve.png")

# Create a figure with a higher DPI
fig, ax = plt.subplots(dpi=150)

# Display the image
ax.imshow(r_curve)
ax.axis("off")

# Show the plot
plt.show()

# %% [markdown]
# **F1_curve**

# %%
# Load the image
r_curve = plt.imread("/content/runs/detect/val/F1_curve.png")

# Create a figure with a higher DPI
fig, ax = plt.subplots(dpi=150)

# Display the image
ax.imshow(r_curve)
ax.axis("off")

# Show the plot
plt.show()

# %% [markdown]
# **Confusion Matrix**

# %%
import matplotlib.pyplot as plt

# Load the image
r_curve = plt.imread("/content/runs/detect/val/confusion_matrix_normalized.png")

# Create a figure with a higher DPI
fig, ax = plt.subplots(dpi=200)

# Display the image
ax.imshow(r_curve)
ax.axis("off")

# Show the plot
plt.show()

# %% [markdown]
# **Visual Results**

# %%
import matplotlib.pyplot as plt

# Load the image
r_curve = plt.imread("/content/runs/detect/val/val_batch1_pred.jpg")

# Create a figure with a higher DPI
fig, ax = plt.subplots(dpi=300)

# Display the image
ax.imshow(r_curve)
ax.axis("off")

# Show the plot
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# **Test YOLO V3 Model on Test images**

# %%
# Run evaluation on the test image set
test_results = model.predict(source="/content/Road-Crack-Detection-Combined-Dataset-2/test/images", save=True)
# Out:
# image 1/167 /content/Road-Crack-Detection-Combined-Dataset-2/test/images/frame1019---Copy_jpg.rf.97797afc733e95ac2025d1d368f58068.jpg: 384x640 1 Crocodile, 1 Longitudinal, 502.3ms
# image 2/167 /content/Road-Crack-Detection-Combined-Dataset-2/test/images/frame1072---Copy_jpg.rf.f6fb519bb6de940f9a56f181b5325462.jpg: 384x640 2 Crocodiles, 1 Transverse, 64.8ms
# image 3/167 /content/Road-Crack-Detection-Combined-Dataset-2/test/images/frame1131---Copy_jpg.rf.c3d5b11f5c4f82c71613b7e556c9356d.jpg: 384x640 (no detections), 64.7ms
# image 4/167 /content/Road-Crack-Detection-Combined-Dataset-2/test/images/frame1171---Copy_jpg.rf.3dace60c37612ded87c6deb48a48cd94.jpg: 384x640 (no detections), 67.8ms
# image 5/167 /content/Road-Crack-Detection-Combined-Dataset-2/test/images/frame1209---Copy_jpg.rf.a905478d978f14ef1926272933a7fde6.jpg: 384x640 (no detections), 57.5ms
# image 6/167 /content/Road-Crack-Detection-Combined-Dataset-2/test/images/frame1231---Copy_jpg.rf.cf0eb4f16f676994ea2cf77f49539d63.jpg: 384x640 (no detections), 69.8ms
# image 7/167 /content/Road-Crack-Detection-Combined-Dataset-2/test/images/frame1232---Copy_jpg.rf.c39afe30eb196d705df8ddf41a8b8a86.jpg: 384x640 1 Crocodile, 63.2ms
# image 8/167 /content/Road-Crack-Detection-Combined-Dataset-2/test/images/frame1240---Copy_jpg.rf.453d6d665f9f4ac4b17701a970a19c4f.jpg: 384x640 1 Crocodile, 1 Longitudinal, 45.0ms
# image 9/167 /content/Road-Crack-Detection-Combined-Dataset-2/test/images/frame1247---Copy_jpg.rf.546558a4f30c6fc151a363a41f3a4fd8.jpg: 384x640 3 Longitudinals, 49.7ms
# image 10/167 /content/Road-Crack-Detection-Combined-Dataset-2/test/images/frame1265---Copy_jpg.rf.0cfa394e9b3287ee56658c57b30275ac.jpg: 384x640 2 Longitudinals, 46.1ms
# image 11/167 /content/Road-Crack-Detection-Combined-Dataset-2/test/images/frame1268---Copy_jpg.rf.7aa85552aba33fc27a06999c1baa1697.jpg: 384x640 2 Longitudinals, 45.8ms
# image 12/167 /content/Road-Crack-Detection-Combined-Dataset-2/test/images/frame1273---Copy_jpg.rf.3698c31a3c7b0558ff816f2d50c805cf.jpg: 384x640 1 Crocodile, 1 Longitudinal, 44.1ms
# image 13/167 /content/Road-Crack-Detection-Combined-Dataset-2/test/images/frame1302---Copy_jpg.rf.ef5d78234c7c94747a34cb3374bbae08.jpg: 384x640 (no detections), 48.0ms
# image 14/167 /content/Road-Crack-Detection-Combined-Dataset-2/test/images/frame1361---Copy_jpg.rf.50ddbaf97c81917c016f4d304506a74a.jpg: 384x640 (no detections), 47.8ms
# image 15/167 /content/Road-Crack-Detection-Combined-Dataset-2/test/images/frame1388---Copy_jpg.rf.d8563a0a99fba0379e01d8ee6fe63cfa.jpg: 384x640 1 Crocodile, 41.7ms
# image 16/167 /content/Road-Crack-Detection-Combined-Dataset-2/test/images/frame1457---Copy_jpg.rf.2dfc68664dfa392c052c2c920798e4e3.jpg: 384x640 2 Crocodiles, 41.8ms
# image 17/167 /content/Road-Crack-Detection-Combined-Dataset-2/test/images/fr
167 /content/Road-Crack-Detection-Combined-Dataset-2/test/images/frame529---Copy_jpg.rf.0eeceaf07372762f17254886510feec3.jpg: 384x640 1 Crocodile, 38.7ms
# image 152/167 /content/Road-Crack-Detection-Combined-Dataset-2/test/images/frame531---Copy_jpg.rf.30bc95d973081c1531239f855457df0b.jpg: 384x640 1 Crocodile, 40.2ms
# image 153/167 /content/Road-Crack-Detection-Combined-Dataset-2/test/images/frame548---Copy_jpg.rf.e317d351910932bd1eb2944019478135.jpg: 384x640 (no detections), 38.6ms
# image 154/167 /content/Road-Crack-Detection-Combined-Dataset-2/test/images/frame599---Copy_jpg.rf.dc53e2d2c7a9ce97dbb88463cc53e5c8.jpg: 384x640 1 Crocodile, 38.8ms
# image 155/167 /content/Road-Crack-Detection-Combined-Dataset-2/test/images/frame635---Copy_jpg.rf.ebb76865468c983ea936bee43fe11002.jpg: 384x640 2 Crocodiles, 38.0ms
# image 156/167 /content/Road-Crack-Detection-Combined-Dataset-2/test/images/frame638_jpg.rf.f1d7d3b78fbf77f3713d3f0f22491171.jpg: 384x640 4 Transverses, 38.8ms
# image 157/167 /content/Road-Crack-Detection-Combined-Dataset-2/test/images/frame645---Copy_jpg.rf.1acffc04913f788345952e9f64c8e530.jpg: 384x640 (no detections), 40.3ms
# image 158/167 /content/Road-Crack-Detection-Combined-Dataset-2/test/images/frame657---Copy_jpg.rf.0b4733a7b8c4c13cf99398ae654c02ad.jpg: 384x640 1 Crocodile, 38.4ms
# image 159/167 /content/Road-Crack-Detection-Combined-Dataset-2/test/images/frame704---Copy_jpg.rf.ad54049f458ff3a181b7127357e3ae19.jpg: 384x640 2 Crocodiles, 1 Transverse, 38.3ms
# image 160/167 /content/Road-Crack-Detection-Combined-Dataset-2/test/images/frame736---Copy_jpg.rf.008b79858eaf573c26d80b66bbc8444b.jpg: 384x640 1 Longitudinal, 39.6ms
# image 161/167 /content/Road-Crack-Detection-Combined-Dataset-2/test/images/frame828---Copy_jpg.rf.6256d67268724c0628ac4d3ebfb69c68.jpg: 384x640 (no detections), 38.1ms
# image 162/167 /content/Road-Crack-Detection-Combined-Dataset-2/test/images/frame861---Copy_jpg.rf.fa800f49431c41d27c2e04a3adabe304.jpg: 384x640 (no detections), 45.0ms
# image 163/167 /content/Road-Crack-Detection-Combined-Dataset-2/test/images/frame868---Copy_jpg.rf.977f530782abbfa3b9e2d286fe862869.jpg: 384x640 (no detections), 38.6ms
# image 164/167 /content/Road-Crack-Detection-Combined-Dataset-2/test/images/frame881---Copy_jpg.rf.c6a73ff7340de25c863b889248fc3c74.jpg: 384x640 (no detections), 40.4ms
# image 165/167 /content/Road-Crack-Detection-Combined-Dataset-2/test/images/frame939---Copy_jpg.rf.f43230f7cdc22c97f6e7ddbfb7aeb25e.jpg: 384x640 2 Crocodiles, 2 Transverses, 39.9ms
# image 166/167 /content/Road-Crack-Detection-Combined-Dataset-2/test/images/frame958---Copy_jpg.rf.18c3f0eab91b8d4da6646152a17447e2.jpg: 384x640 4 Crocodiles, 38.3ms
# image 167/167 /content/Road-Crack-Detection-Combined-Dataset-2/test/images/frame977---Copy_jpg.rf.0f0dbd4e3c8f5b1fd53fc54938df3386.jpg: 384x640 5 Crocodiles, 40.2ms
# Speed: 3.5ms preprocess, 42.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict

# %%
import os
import random
import matplotlib.pyplot as plt
from PIL import Image

# Directory containing images
image_dir = '/content/runs/detect/predict'

# Get a list of all files in the directory
all_files = os.listdir(image_dir)

# Filter out non-image files (optional, based on common image extensions)
image_files = [file for file in all_files if file.lower().endswith(('png', 'jpg', 'jpeg', 'gif', 'bmp', 'tiff'))]

# Randomly select 10 images
random_images = random.sample(image_files, 10)

# Create a figure
fig, axes = plt.subplots(2, 5, figsize=(25, 5))

# Flatten axes for easy iteration
axes = axes.flatten()

for ax, img_file in zip(axes, random_images):
    # Load image
    img_path = os.path.join(image_dir, img_file)
    img = Image.open(img_path)

    # Display image
    ax.imshow(img)
    #ax.set_title(img_file)
    ax.axis('off')  # Hide axes

plt.tight_layout()
plt.show()
